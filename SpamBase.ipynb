# %% [markdown]
# # SpamBase.py

# %% [markdown]
# # Imports

# %%
# pip install ucimlrepo
import pandas as pd
import numpy as np
import sys 
import matplotlib.pyplot as plt  

from ucimlrepo import fetch_ucirepo, list_available_datasets

# Check Which Dataset can be imported
#list_available_datasets()

# %% [markdown]
# ## Open regression.py

# %%
#sys.path.append("Model_Implement") 
from regression import LogReg
from regression import KNN

# %% [markdown]
# # Fetch Datasets

# %%
# fetch dataset 
spambase = fetch_ucirepo(id=94) 
  
# data (as pandas dataframes) 
X = spambase.data.features 
y = spambase.data.targets

# %%
# metadata 
#print(spambase.metadata) 
  
# variable information 
#print(spambase.variables) 
#print(spambase.data.targets)

# %% [markdown]
# # Clean Dataset

# %% [markdown]
# ## Clean Missing Value from X

# %% [markdown]
# ## Drop Duplicate Rows

# %%
# drops duplicate rows
X_cleaned = X_cleaned.drop_duplicates(ignore_index=False)
X_cleaned
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 0                0.00            0.00  ...                   0.0        0.000
# 1                0.00            0.94  ...                   0.0        0.000
# 2                0.64            0.25  ...                   0.0        0.010
# 3                0.31            0.63  ...                   0.0        0.000
# 4                0.31            0.63  ...                   0.0        0.000
# ...               ...             ...  ...                   ...          ...
# 4596             0.00            0.00  ...                   0.0        0.000
# 4597             0.00            0.00  ...                   0.0        0.000
# 4598             0.00            0.00  ...                   0.0        0.102
# 4599             0.00            0.00  ...                   0.0        0.000
# 4600             0.00            0.00  ...                   0.0        0.000
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000          0.0        0.778        0.000        0.000
# 1           0.132          0.0        0.372        0.180        0.048
# 2           0.143          0.0        0.276        0.184        0.010
# 3           0.137          0.0        0.137        0.000        0.000
# 4           0.135          0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 4596        0.232          0.0        0.000        0.000        0.000
# 4597        0.000          0.0        0.353        0.000        0.000
# 4598        0.718          0.0        0.000        0.000        0.000
# 4599        0.057          0.0        0.000        0.000        0.000
# 4600        0.000          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total
# 0                          278
# 1                         1028
# 2                         2259
# 3                          191
# 4                          191
# ...                        ...
# 4596                        88
# 4597                        14
# 4598                       118
# 4599                        78
# 4600                        40
#
# [4207 rows x 57 columns]

# %% [markdown]
# # Plot Data Points in Map

# %%
List=[]
i=0
sizeOfY =y.shape[0]#number of rows

while i< (sizeOfY):#iterate through rows
    value= y.iat[i,0]#grab value in table for each row
    List.append(value)
        
    i+=1


plt.figure()#creates template
plt.plot(List)#plot

plt.grid()
plt.show()#displays graph

# %% [markdown]
# # Running The Model

# %%
y = np.array(y) #(4601, 1)
X = np.array(X) #(4601, 57)

lr = LogReg(learning_rate=0.000000001, num_epochs=100)
losses = lr.fit(X, y)


accuracy = lr.evaluate_acc(X, y)
print('Accuracy: ', accuracy)
# Out:
# Epoch: 0, Loss: 3189.1701777561298
# Epoch: 1, Loss: 3170.1580547782073
# Epoch: 2, Loss: 3167.7039402028777
# Epoch: 3, Loss: 3167.1438827884613
# Epoch: 4, Loss: 3166.9998985359675
# Epoch: 5, Loss: 3166.960979217729
# Epoch: 6, Loss: 3166.9501410574017
# Epoch: 7, Loss: 3166.9470142625896
# Epoch: 8, Loss: 3166.946034229084
# Epoch: 9, Loss: 3166.945656077047
# Epoch: 10, Loss: 3166.945447300692
# Epoch: 11, Loss: 3166.945286282048
# Epoch: 12, Loss: 3166.945138743424
# Epoch: 13, Loss: 3166.9449950118706
# Epoch: 14, Loss: 3166.9448523559545
# Epoch: 15, Loss: 3166.944710004127
# Epoch: 16, Loss: 3166.944567738387
# Epoch: 17, Loss: 3166.94442549716
# Epoch: 18, Loss: 3166.944283263025
# Epoch: 19, Loss: 3166.944141031074
# Epoch: 20, Loss: 3166.9439987999126
# Epoch: 21, Loss: 3166.9438565691426
# Epoch: 22, Loss: 3166.943714338665
# Epoch: 23, Loss: 3166.943572108435
# Epoch: 24, Loss: 3166.943429878461
# Epoch: 83, Loss: 3166.935038739124
# Epoch: 84, Loss: 3166.934896523697
# Epoch: 85, Loss: 3166.9347543085187
# Epoch: 86, Loss: 3166.9346120935884
# Epoch: 87, Loss: 3166.9344698788786
# Epoch: 88, Loss: 3166.9343276644317
# Epoch: 89, Loss: 3166.934185450216
# Epoch: 90, Loss: 3166.9340432362565
# Epoch: 91, Loss: 3166.933901022525
# Epoch: 92, Loss: 3166.9337588090434
# Epoch: 93, Loss: 3166.9336165958052
# Epoch: 94, Loss: 3166.9334743828003
# Epoch: 95, Loss: 3166.9333321700465
# Epoch: 96, Loss: 3166.9331899575386
# Epoch: 97, Loss: 3166.9330477452622
# Epoch: 98, Loss: 3166.932905533233
# Epoch: 99, Loss: 3166.932763321444
# Accuracy:  0.6059552271245382

# %%
plt.grid()
plt.plot(losses)

# %%
knn = KNN(k=4)
accuracy_k_fold = KNN.k_fold_cross_validation(knn, X, y, k=5)
print("5-Fold Cross-Validation Accuracy:", accuracy_k_fold)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ferna\OneDrive\Documents\GitHub\Mini-Project-1\SpamBase.ipynb Cell 19 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> knn = KNN(k=4)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> accuracy_k_fold = KNN.k_fold_cross_validation(knn, X, y, k=5)
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> print("5-Fold Cross-Validation Accuracy:", accuracy_k_fold)
#
# File c:\Users\ferna\OneDrive\Documents\GitHub\Mini-Project-1\regression.py:107, in KNN.k_fold_cross_validation(self, X, y, k)
#     104     y_test = y[start_idx:end_idx]
#     106     self.fit(X_train, y_train)
# --> 107     accuracy = self.evaluate_accuracy(X_test, y_test)
#     108     accuracy_scores.append(accuracy)
#     110 return accuracy_scores
#
# File c:\Users\ferna\OneDrive\Documents\GitHub\Mini-Project-1\regression.py:113, in KNN.evaluate_accuracy(self, X, y)
#     112 def evaluate_accuracy(self, X, y):
# --> 113     predictions = self.predict(X)
#     114     return np.mean(predictions == y)
#
# File c:\Users\ferna\OneDrive\Documents\GitHub\Mini-Project-1\regression.py:83, in KNN.predict(self, X)
#      82 def predict(self, X):
# ---> 83     predictions = [self._predict(x) for x in X]
#      84     return np.array(predictions)
#
# File c:\Users\ferna\OneDrive\Documents\GitHub\Mini-Project-1\regression.py:90, in KNN._predict(self, x)
#      88 k_indices = np.argsort(distances)[:self.k]
#      89 k_nearest_labels = [self.y_train[i] for i in k_indices]
# ---> 90 most_common = np.bincount(k_nearest_labels).argmax()
#      91 return most_common
#
# ValueError: object too deep for desired array

# %%
#plt.plot(accuracy_k_fold)
