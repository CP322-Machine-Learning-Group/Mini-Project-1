# %% [markdown]
# # Carseval.py

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import sys 
import matplotlib.pyplot as plt  

from ucimlrepo import fetch_ucirepo, list_available_datasets

# Check Which Dataset can be imported
#list_available_datasets()

# %% [markdown]
# ## Open regression.py

# %%
#sys.path.append("Model_Implement") 
from regression import LogReg

# %% [markdown]
# # Fetch Datasets

# %%
# fetch dataset 
spambase = fetch_ucirepo(id=94) 
  
# data (as pandas dataframes) 
X = spambase.data.features 
y = spambase.data.targets

# %%
# metadata 
#print(spambase.metadata) 
  
# variable information 
#print(spambase.variables) 
#print(spambase.data.targets)

# %% [markdown]
# # Clean Dataset

# %% [markdown]
# ## Clean Missing Value from X

# %%
# removes missing values from X
X_cleaned = X.dropna()
X_cleaned
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 0                0.00            0.00  ...                   0.0        0.000
# 1                0.00            0.94  ...                   0.0        0.000
# 2                0.64            0.25  ...                   0.0        0.010
# 3                0.31            0.63  ...                   0.0        0.000
# 4                0.31            0.63  ...                   0.0        0.000
# ...               ...             ...  ...                   ...          ...
# 4596             0.00            0.00  ...                   0.0        0.000
# 4597             0.00            0.00  ...                   0.0        0.000
# 4598             0.00            0.00  ...                   0.0        0.102
# 4599             0.00            0.00  ...                   0.0        0.000
# 4600             0.00            0.00  ...                   0.0        0.000
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000          0.0        0.778        0.000        0.000
# 1           0.132          0.0        0.372        0.180        0.048
# 2           0.143          0.0        0.276        0.184        0.010
# 3           0.137          0.0        0.137        0.000        0.000
# 4           0.135          0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 4596        0.232          0.0        0.000        0.000        0.000
# 4597        0.000          0.0        0.353        0.000        0.000
# 4598        0.718          0.0        0.000        0.000        0.000
# 4599        0.057          0.0        0.000        0.000        0.000
# 4600        0.000          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total
# 0                          278
# 1                         1028
# 2                         2259
# 3                          191
# 4                          191
# ...                        ...
# 4596                        88
# 4597                        14
# 4598                       118
# 4599                        78
# 4600                        40
#
# [4601 rows x 57 columns]

# %% [markdown]
# ## Drop Duplicate Rows

# %%
# drops duplicate rows
X_cleaned = X_cleaned.drop_duplicates(ignore_index=False)
X_cleaned
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 0                0.00            0.00  ...                   0.0        0.000
# 1                0.00            0.94  ...                   0.0        0.000
# 2                0.64            0.25  ...                   0.0        0.010
# 3                0.31            0.63  ...                   0.0        0.000
# 4                0.31            0.63  ...                   0.0        0.000
# ...               ...             ...  ...                   ...          ...
# 4596             0.00            0.00  ...                   0.0        0.000
# 4597             0.00            0.00  ...                   0.0        0.000
# 4598             0.00            0.00  ...                   0.0        0.102
# 4599             0.00            0.00  ...                   0.0        0.000
# 4600             0.00            0.00  ...                   0.0        0.000
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000          0.0        0.778        0.000        0.000
# 1           0.132          0.0        0.372        0.180        0.048
# 2           0.143          0.0        0.276        0.184        0.010
# 3           0.137          0.0        0.137        0.000        0.000
# 4           0.135          0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 4596        0.232          0.0        0.000        0.000        0.000
# 4597        0.000          0.0        0.353        0.000        0.000
# 4598        0.718          0.0        0.000        0.000        0.000
# 4599        0.057          0.0        0.000        0.000        0.000
# 4600        0.000          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total
# 0                          278
# 1                         1028
# 2                         2259
# 3                          191
# 4                          191
# ...                        ...
# 4596                        88
# 4597                        14
# 4598                       118
# 4599                        78
# 4600                        40
#
# [4207 rows x 57 columns]

# %% [markdown]
# # Plot Data Points in Map

# %%
List=[]
i=0
sizeOfY =y.shape[0]#number of rows

while i< (sizeOfY):#iterate through rows
    value= y.iat[i,0]#grab value in table for each row
    List.append(value)
        
    i+=1


plt.figure()#creates template
plt.plot(List)#plot

plt.grid()
plt.show()#displays graph

# %% [markdown]
# # Running The Model

# %%
y = np.array(y).reshape(-1)
X = np.array(X)

lr = LogReg(learning_rate=0.01, num_epochs=1000)
lr.fit(X, y)

accuracy = lr.evaluate_acc(X, y)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Chetas\Documents\GitHub\Mini-Project-1\SpamBase.ipynb Cell 17 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Chetas/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> X = np.array(X)
#       <a href='vscode-notebook-cell:/c%3A/Users/Chetas/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> lr = LogReg(learning_rate=0.01, num_epochs=1000)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Chetas/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> lr.fit(X, y)
#       <a href='vscode-notebook-cell:/c%3A/Users/Chetas/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> accuracy = lr.evaluate_acc(X, y)
#       <a href='vscode-notebook-cell:/c%3A/Users/Chetas/Documents/GitHub/Mini-Project-1/SpamBase.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> print(accuracy)
#
# File c:\Users\Chetas\Documents\GitHub\Mini-Project-1\regression.py:33, in LogReg.fit(self, X, y)
#      30 y = y.reshape(-1)
#      32 for _ in range(self.num_epochs):
# ---> 33     z = np.dot(X, self.theta) + self.bias
#      34     h = self.sigmoid_function(z)
#      35     loss = self.logistic_loss(h, y)
#
# AttributeError: 'LogReg' object has no attribute 'bias'
